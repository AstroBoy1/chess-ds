# %% [markdown]
# <a href="https://colab.research.google.com/github/AstroBoy1/chess-ds/blob/master/scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
import pandas as pd
import re

# %% [markdown]
# # Classes

# %%
class User:
    """Dimension table"""
    def __init__(self, user_id, gender, state):
        self.user_id = user_id
        self.gender = gender
        self.state = state


class UserEvents:
    """Dimension table"""
    def __init__(self, event_id, user_id, date, event_name, reg_before, reg_after, quick_before, quick_after,
                 blitz_before, blitz_after, section, state):
        self.event_id = event_id
        self.user_id = user_id
        self.date = date
        self.event_name = event_name
        self.reg_before = reg_before
        self.reg_after = reg_after
        self.quick_before = quick_before
        self.quick_after = quick_after
        self.blitz_before = blitz_before
        self.blitz_after = blitz_after
        self.section = section
        self.state = state

# %% [markdown]
# # Methods

# %%
def simple_get(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200
            and content_type is not None
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors.
    This function just prints them, but you can
    make it do anything.
    """
    print(e)


def get_user_info(parsed_html, user_id, users_list):
    """Takes in html from beautiful soup, finds the gender and state, and returns a user object"""
    s = str(parsed_html)
    st = s.strip()
    if "Error" in st:
        print("Non-existent player")
        return -1
    state_index = st.index("State")
    gender_index = st.index("Gender")
    s = st[state_index + 21: state_index + 23]
    g = st[gender_index + 22: gender_index + 23]
    users_list.append(User(user_id, g, s))
    return 0


def rating_helper(rating_string):
    """Gets the before and after rating for one instance with simple processing"""
    rating_split = rating_string.split("=>")
    first, second = rating_split[0].strip(), rating_split[1].strip()
    return first, second


def get_event_ratings(parsed_html, user_id, user_events_list):
    """Takes in the html from beautiful soup and gets the tournament event id, dates, and ratings"""
    if "Error" in str(parsed_html):
        return -1
    table = parsed_html.find('table', {'valign': 'top', 'width': '960', 'cellspacing': '0', 'cellpadding': '4', 'border': '1'})
    if table:
        dates = table.find_all("td", {'width': '120'})
        tournaments = table.find_all("td", {'width': '350'})
        ratings = table.find_all("td", {'width': '160'})
        rating_i = 0
        for d, t in zip(dates, tournaments):
            d_s = d.getText()
            parsed_date = d_s[:10]
            parsed_event_id = d_s[10:]
            t_text = t.getText()
            # Matches anything that starts with ( and ends with ), .* says there can be zero or more of any characters
            match = re.search("\(.*\)", t_text)
            start, end = match.span()
            section = t_text[end:]
            state = t_text[start + 1:end - 1]
            tournament_name = t_text[:start - 1]
            reg_ratings = ratings[rating_i].getText()
            quick_ratings = ratings[rating_i + 1].getText()
            blitz_ratings = ratings[rating_i + 2].getText()
            rating_i += 3
            reg_rating_before, reg_rating_after, quick_rating_before, quick_rating_after, blitz_rating_before, \
                blitz_rating_after = None, None, None, None, None, None
            if "=>" in reg_ratings:
                reg_rating_before, reg_rating_after = rating_helper(reg_ratings)
            if "=>" in quick_ratings:
                quick_rating_before, quick_rating_after = rating_helper(quick_ratings)
            if "=>" in blitz_ratings:
                blitz_rating_before, blitz_rating_after = rating_helper(blitz_ratings)
            ue = UserEvents(parsed_event_id, user_id, parsed_date, tournament_name, reg_rating_before, reg_rating_after,
                            quick_rating_after, quick_rating_after, blitz_rating_before, blitz_rating_after, section,
                            state)
            user_events_list.append(ue)
        return 0
    else:
        return -1

# %% [markdown]
# # Main

# %%
user_df = pd.DataFrame()
user_events_df = pd.DataFrame()
user_events = []
users = []
user_id_list = []
gender_list = []
state_list = []
event_id_list = []
user_id_event_list = []
date_list = []
event_name_list = []
reg_before_list = []
reg_after_list = []
quick_before_list = []
quick_after_list = []
blitz_before_list = []
blitz_after_list = []
section_list = []
state_event_list = []
'''TODO: Store the data in a sqlite database, some testing, make the adding class members to a list more efficient'''
for i in range(1, 2):
    uid = str(1243502) + str(i)
    page = "http://www.uschess.org/msa/MbrDtlMain.php?" + uid
    rating_page = "http://www.uschess.org/msa/MbrDtlTnmtHst.php?" + uid
    # Pages then go http://www.uschess.org/msa/MbrDtlTnmtHst.php?12641216.2
    # http://www.uschess.org/msa/MbrDtlTnmtHst.php?12641216.3
    # http://www.uschess.org/msa/MbrDtlTnmtHst.php?12641216.11
    # and so forth
    raw_html = simple_get(page)
    html = BeautifulSoup(raw_html, 'html.parser')
    get_user_info(html, uid, users)
    
    count = 1
    event_return = 0
    while event_return != -1:
        rating_page = "http://www.uschess.org/msa/MbrDtlTnmtHst.php?12641216" + "." + str(count)
        raw_html = simple_get(rating_page)
        html = BeautifulSoup(raw_html, 'html.parser')
        event_return = get_event_ratings(html, uid, user_events)
        count += 1

# %%
for user in users:
    user_id_list.append(user.user_id)
    gender_list.append(user.gender)
    state_list.append(user.state)
user_df['uid'] = user_id_list
user_df['gender'] = gender_list
user_df['state'] = state_list

# %%
user_df.head
# Out:
# <bound method NDFrame.head of         uid gender state
# 0  12435021      M    NY>

# %%
for ue in user_events:
    event_id_list.append(ue.event_id)
    user_id_event_list.append(ue.user_id)
    date_list.append(ue.date)
    event_name_list.append(ue.event_name)
    reg_before_list.append(ue.reg_before)
    reg_after_list.append(ue.reg_after)
    quick_before_list.append(ue.quick_before)
    quick_after_list.append(ue.quick_after)
    blitz_before_list.append(ue.blitz_before)
    blitz_after_list.append(ue.blitz_after)
    section_list.append(ue.section)
    state_event_list.append(ue.state)
user_events_df['event_id'] = event_id_list
user_events_df['uid'] = user_id_event_list
user_events_df['date'] = date_list
user_events_df['event_name'] = event_name_list
user_events_df['reg_before'] = reg_before_list
user_events_df['reg_after'] = reg_after_list
user_events_df['quick_before'] = quick_before_list
user_events_df['quick_after'] = quick_after_list
user_events_df['blitz_before'] = blitz_before_list
user_events_df['blitz_after'] = blitz_after_list
user_events_df['section'] = section_list
user_events_df['state'] = state_event_list

# %%
user_events_df
# Out:
#           event_id       uid        date                      event_name  \
# 0    201902240752   12435021  2019-02-24  2019 CHAMPIONS SHOWDOWN: THE K
# 1    201902240752   12435021  2019-02-22  2019 CHAMPIONS SHOWDOWN: THE K
# 2    201812167742   12435021  2018-12-16  LONDON CLASSIC CHESS TOUR FINA
# 3    201810281352   12435021  2018-10-28  CHESS.COM ISLE OF MAN INTL MAS
# 4    201810051302   12435021  2018-10-05            43RD WORLD OPLYMPIAD
# 5    201808283502   12435021  2018-08-27            2018 SINQUEFIELD CUP
# 6    201808150662   12435021  2018-08-15    2018 ST. LOUIS RAPID & BLITZ
# 7    201808150662   12435021  2018-08-15    2018 ST. LOUIS RAPID & BLITZ
# 8    201806071952   12435021  2018-06-07          Altibox Norway Classic
# 9    201804296852   12435021  2018-04-29            2018 US CHAMPIONSHIP
# 10   201802016662   12435021  2018-02-01      Tradewise Festival Masters
# 11   201712113872   12435021  2017-12-11            LONDON CHESS CLASSIC
# 12   201711256902   12435021  2017-11-25    GRAND PRIX PALMA DE MALLORCA
# 13   201711149852   12435021  2017-11-12         2017 CHAMPIONS SHOWDOWN
# 14   201711149852   12435021  2017-11-11         2017 CHAMPIONS SHOWDOWN
# 15   201711149852   12435021  2017-11-10         2017 CHAMPIONS SHOWDOWN
# 16   201711149852   12435021  2017-11-09         2017 CHAMPIONS SHOWDOWN
# 17   201710018822   12435021  2017-10-01          CHESS.COM INTL MASTERS
# 18   201709282032   12435021  2017-09-28                  World Cup 2017
# 19   201708180002   12435021  2017-08-18  2017 GCT ST LOUIS RAPID & BLIT
# 20   201708180002   12435021  2017-08-18  2017 GCT ST LOUIS RAPID & BLIT
# 21   201708118372   12435021  2017-08-11            2017 SINQUEFIELD CUP
# 22   201706161052   12435021  2017-06-16            ALTIBOX NORWAY CHESS
# 23   201705228582   12435021  2017-05-22          FIDE Grand Prix Moscow
# 24   201704094552   12435021  2017-04-09            2017 US CHAMPIONSHIP
# 25   201702171262   12435021  2017-02-17         FIDE Grand Prix Sharjah
# 26   201701241232   12435021  2017-01-24               Tradewise Masters
# 27   201612094052   12435021  2016-12-09            London Chess Classic
# 28   201610019062   12435021  2016-10-01                  ISLE OF MAN IM
# 29   201609015912   12435021  2016-09-01        42ND WORLD OLYMPIAD OPEN
# ..             ...       ...         ...                             ...
# 480  199603241640   12435021  1996-03-24  PS 9 It's Spring Chess Tournam
# 481  199603172720   12435021  1996-03-17              HUDSON VALLEY OPEN
# 482  199603172720   12435021  1996-03-17              HUDSON VALLEY OPEN
# 483  199603101810   12435021  1996-03-10  29th New York State Scholastic
# 484  199603311740   12435021  1996-03-31                        HCES #75
# 485  199602192110   12435021  1996-02-19      US AMT TEAM EAST CHAMPIONS
# 486  199601141130   12435021  1996-01-14  31ST ANNUAL GREATER NY SCHOLAS
# 487  199602119270   12435021  1996-02-11    JUNIOR CHESS CONGRESS - EAST
# 488  199602048510   12435021  1996-02-04  FIRST SUNDAY OF THE MONTH QUAD
# 489  199601286530   12435021  1996-01-28                        HCES #73
# 490  199601214790   12435021  1996-01-21       GREENBURGH WINTER CLASSIC
# 491  199512319560   12435021  1995-12-31      YOUR LAST BLUNDER IN 1995!
# 492  199512106670   12435021  1995-12-10                        HCES #72
# 493  199512096680   12435021  1995-12-09  WHITE PLAINS NO SNOW SCHOLASTI
# 494  199512035400   12435021  1995-12-03  1995 NATIONAL K-12 GRADE CHAMP
# 495  199511265470   12435021  1995-11-26         NATIONAL CHESS CONGRESS
# 496  199511128890   12435021  1995-11-12  5TH GREENWICH COUNTRY DAY SCHO
# 497  199511190010   12435021  1995-11-19                        HCES #71
# 498  199511056160   12435021  1995-11-05   1ST SUNDAY OF THE MONTH QUADS
# 499  199510080590   12435021  1995-10-08                        HCES #70
# 500  199510151880   12435021  1995-10-15         GREENBURGH FALL CLASSIC
# 501  199509300580   12435021  1995-09-30      WHITE PLAINS SEASON OPENER
# 502  199509043850   12435021  1995-09-04           55TH NEW ENGLAND OPEN
# 503  199507090090   12435021  1995-07-09   1ST SUNDAY OF THE MONTH QUADS
# 504  199504303340   12435021  1995-04-30  NORTHERN NEW ENGLAND ELEMENTAR
# 505  199504092250   12435021  1995-04-09  1995 NATIONAL ELEMENTARY CHAMP
# 506  199504010210   12435021  1995-04-01       HUDSON VALLEY PRIM & ELEM
# 507  199503257670   12435021  1995-03-25  WHITE PLAINS SPRING SCHOLASTIC
# 508  199503044630   12435021  1995-03-04   White Plains March Scholastic
# 509  199501169440   12435021  1995-01-16      Junior Chess Congress East
#
#     reg_before  reg_after quick_before quick_after blitz_before blitz_after  \
# 0         None       None         None        None         2910        2910
# 1         None       None         2820        2820         None        None
# 2         2818       2824         None        None         None        None
# 3         2815       2818         None        None         None        None
# 4         2839       2815         None        None         None        None
# 5         2857       2839         None        None         None        None
# 6         None       None         None        None         2909        2910
# 7         2852       2857         2816        2816         None        None
# 8         2841       2852         None        None         None        None
# 9         2863       2841         None        None         None        None
# 10        2855       2863         None        None         None        None
# 11        2855       2855         None        None         None        None
# 12        2853       2855         None        None         None        None
# 13        None       None         None        None         2878        2909
# 14        None       None         None        None         2878        2878
# 15        None       None         2804        2804         None        None
# 16        2851       2853         2805        2805         None        None
# 17        2842       2851         None        None         None        None
# 18        2852       2842         None        None         None        None
# 19        2850       2852         2809        2809         None        None
# 20        None       None         None        None         2868        2878
# 21        2867       2850         None        None         None        None
# 22        2857       2867         None        None         None        None
# 23        2859       2857         None        None         None        None
# 24        2867       2859         None        None         None        None
# 25        2870       2867         None        None         None        None
# 26        2858       2870         None        None         None        None
# 27        2849       2858         None        None         None        None
# 28        2861       2849         None        None         None        None
# 29        2864       2861         None        None         None        None
# ..         ...        ...          ...         ...          ...         ...
# 480       1194       1248         None        None         None        None
# 481       1201       1194         None        None         None        None
# 482       1204       1201         None        None         None        None
# 483       1200       1204         None        None         None        None
# 484       1209       1200         None        None         None        None
# 485       1205       1221         None        None         None        None
# 486       1221       1209         None        None         None        None
# 487       1211       1205         None        None         None        None
# 488       1227       1211         None        None         None        None
# 489       1224       1227         None        None         None        None
# 490       1195       1224         None        None         None        None
# 491       1166       1195         None        None         None        None
# 492       1148       1166         None        None         None        None
# 493       1142       1148         None        None         None        None
# 494       1110       1142         None        None         None        None
# 495       1161       1110         None        None         None        None
# 496        990       1026         None        None         None        None
# 497        983        990         None        None         None        None
# 498        976        983         None        None         None        None
# 499        903        976         None        None         None        None
# 500        857        903         None        None         None        None
# 501        781        857         None        None         None        None
# 502        795        781         None        None         None        None
# 503        788        795         None        None         None        None
# 504        788        788         None        None         None        None
# 505        787        788         None        None         None        None
# 506  702 (P14)  787 (P18)         None        None         None        None
# 507  718 (P10)  702 (P14)         None        None         None        None
# 508   684 (P6)  718 (P10)         None        None         None        None
# 509  (Unrated)   684 (P6)         None        None         None        None
#
#                           section   state
# 0          7: NAKAMURA-DUDA BLITZ      MO
# 1          2: NAKAMURA-DUDA RAPID      MO
# 2    1: LONDON CLASSIC CHESS TOUR     ENG
# 3    1: CHESS.COM ISLE OF MAN INT     ENG
# 4         1: 43RD WORLD OPLYMPIAD     GEO
# 5                           1: RR      MO
# 6                        2: BLITZ      MO
# 7                        1: RAPID      MO
# 8       1: Altibox Norway Classic     NOR
# 9         1: 2018 US CHAMPIONSHIP      MO
# 10   1: Tradewise Festival Master     ENG
# 11        1: LONDON CHESS CLASSIC     ENG
# 12   1: GRAND PRIX PALMA DE MALLO     ESP
# 13     13: G5 NAKAMURA VS TOPALOV      MO
# 14     9: G10 NAKAMURA VS TOPALOV      MO
# 15     5: G20 NAKAMURA VS TOPALOV      MO
# 16     1: G30 NAKAMURA VS TOPALOV      MO
# 17      1: CHESS.COM INTL MASTERS     ENG
# 18              1: World Cup 2017     GEO
# 19                       1: RAPID      MO
# 20                       2: BLITZ      MO
# 21        1: 2017 SINQUEFIELD CUP      MO
# 22        1: ALTIBOX NORWAY CHESS  NORWAY
# 23      1: FIDE Grand Prix Moscow     RUS
# 24        1: 2017 US CHAMPIONSHIP      MO
# 25     1: FIDE Grand Prix Sharjah     UAE
# 26           1: Tradewise Masters     ENG
# 27              1: London Classic     ENG
# 28              1: ISLE OF MAN IM     ENG
# 29    1: 42ND WORLD OLYMPIAD OPEN     AZE
# ..                            ...     ...
# 480                  5: Over 1100      NY
# 481                 3: UNDER 1500      NY
# 482                 2: UNDER 1800      NY
# 483                    2: Primary      NY
# 484                 1: CHAMPIONSH      NY
# 485                       1: OPEN      NJ
# 486                 8: PRIM. OPEN      NY
# 487                    9: 8 CHAMP      CT
# 488                          9: 9      NJ
# 489                 1: CHAMPIONSH      NY
# 490                 1: CHAMPIONSH      NY
# 491                           1:       NY
# 492                    2: RESERVE      NY
# 493                 3: ELEMENTARY      NY
# 494                    4: GRADE 2      NY
# 495                 7: UNDER 1200      PA
# 496                    4: PRIMARY      CT
# 497                    2: Reserve      NY
# 498                    12: SEC 12      NJ
# 499                    3: PRIMARY      NY
# 500                    4: PRIMARY      NY
# 501                    3: PRIMARY      NY
# 502                     7: SUNDAY      CT
# 503                  8: SECTION 8      NJ
# 504                           1:       VT
# 505                   3: K-3 Open      AR
# 506                    1: PRIMARY      NY
# 507                  3: PRIMARY -      NY
# 508                  1: B PRIMARY      NY
# 509                    4: PRIM 8R      CT
#
# [510 rows x 12 columns]
